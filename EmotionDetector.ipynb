# %%
# !pip install -q kaggle
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-dd56e3d4-3ee2-4c31-b1d6-4ba7d1394210" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-dd56e3d4-3ee2-4c31-b1d6-4ba7d1394210">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !rm -r ~/.kaggle
# !mkdir ~/.kaggle
# !mv ./kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# Out:
# rm: cannot remove '/root/.kaggle': No such file or directory

# %%
# !pwd
# Out:
# /content

# %%
# !kaggle datasets list
import shutil
import os
# Out:
# ref                                                       title                                              size  lastUpdated          downloadCount  voteCount  usabilityRating
# --------------------------------------------------------  ------------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# arnabchaki/data-science-salaries-2023                     Data Science Salaries 2023 💸                       25KB  2023-04-13 09:55:16          13660        367  1.0
# chitrakumari25/corona-virus-latest-data-2023              Corona virus latest data 2023                      10KB  2023-04-29 16:00:51           1135         32  1.0
# utkarshx27/starbucks-nutrition                            Starbucks Nutrition Facts                           2KB  2023-05-10 05:42:59            660         26  1.0
# ...

# %%
# !kaggle datasets download -d royaldreams/face-emotion
# !kaggle datasets download -d ananthu017/emotion-detection-fer
# !kaggle datasets download -d msambare/fer2013
# Out:
# ...
#  96% 69.0M/71.9M [00:05<00:00, 15.6MB/s]
# 100% 71.9M/71.9M [00:05<00:00, 14.7MB/s]
# ...
#  98% 64.0M/65.2M [00:04<00:00, 19.5MB/s]
# 100% 65.2M/65.2M [00:04<00:00, 15.2MB/s]
# ...
#  99% 60.0M/60.3M [00:03<00:00, 23.2MB/s]
# 100% 60.3M/60.3M [00:03<00:00, 16.2MB/s]

# %%
# !pwd
# Out:
# /content

# %%
# !unzip face-emotion.zip
# !unzip emotion-detection-fer.zip -d emotion_detection_fer
# !unzip fer2013.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: train/sad/Training_65242339.jpg
#   inflating: train/sad/Training_65267116.jpg
#   inflating: train/sad/Training_65275626.jpg
#   inflating: train/sad/Training_6529266.jpg
#   inflating: train/sad/Training_65329617.jpg
#   inflating: train/sad/Training_65338712.jpg
#   inflating: train/sad/Training_65338797.jpg
#   inflating: train/sad/Training_65387162.jpg
#   inflating: train/sad/Training_65404494.jpg
#   inflating: train/sad/Training_65426218.jpg
#   inflating: train/sad/Training_65430136.jpg
#   inflating: train/sad/Training_65437377.jpg
#   inflating: train/sad/Training_6545735.jpg
#   inflating: train/sad/Training_65463385.jpg
#   inflating: train/sad/Training_65473985.jpg
#   inflating: train/sad/Training_65502829.jpg
#   inflating: train/sad/Training_65505359.jpg
#   inflating: train/sad/Training_65508578.jpg
#   inflating: train/sad/Training_65516023.jpg
#   inflating: train/sad/Training_65524027.jpg
# ...

# %%
import os
import shutil
#Joining training data

#Happy

trainsource_dir1 = "/content/emotion_detection_fer/train/happy"
trainsource_dir2 = "/content/train/happy"
trainsource_dir3 = "/content/val/val/Happy"
# trainsource_dir4 = "/content/train/train/Happy"
train_dir = "/content/trainmerged/Happy"

# Create the destination directory if it doesn't exist
if not os.path.exists(train_dir):
    os.makedirs(train_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(trainsource_dir1):
    shutil.copy(os.path.join(trainsource_dir1, file_name), train_dir)

# Copy the files from the second source directory to the destination directory
for file_name in os.listdir(trainsource_dir2):
    shutil.copy(os.path.join(trainsource_dir2, file_name), train_dir)


#Angry

trainsource_dir1 = "/content/emotion_detection_fer/train/angry"
trainsource_dir2 = "/content/train/angry"
trainsource_dir3 = "/content/val/val/Angry"
# trainsource_dir4 = "/content/train/train/Angry"
train_dir = "/content/trainmerged/Angry"

# Create the destination directory if it doesn't exist
if not os.path.exists(train_dir):
    os.makedirs(train_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(trainsource_dir1):
    shutil.copy(os.path.join(trainsource_dir1, file_name), train_dir)

# Copy the files from the second source directory to the destination directory
for file_name in os.listdir(trainsource_dir2):
    shutil.copy(os.path.join(trainsource_dir2, file_name), train_dir)

#Disgust

trainsource_dir1 = "/content/emotion_detection_fer/train/disgusted"
trainsource_dir2 = "/content/train/disgust"
trainsource_dir3 = "/content/val/val/Disgust"
# trainsource_dir4 = "/content/train/train/Disgust"
train_dir = "/content/trainmerged/Disgust"

# Create the destination directory if it doesn't exist
if not os.path.exists(train_dir):
    os.makedirs(train_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(trainsource_dir1):
    shutil.copy(os.path.join(trainsource_dir1, file_name), train_dir)

# Copy the files from the second source directory to the destination directory
for file_name in os.listdir(trainsource_dir2):
    shutil.copy(os.path.join(trainsource_dir2, file_name), train_dir)


#Fear

trainsource_dir1 = "/content/emotion_detection_fer/train/fearful"
trainsource_dir2 = "/content/train/fear"
trainsource_dir3 = "/content/val/val/Fear"
# trainsource_dir4 = "/content/train/train/Fear"
train_dir = "/content/trainmerged/Fear"

# Create the destination directory if it doesn't exist
if not os.path.exists(train_dir):
    os.makedirs(train_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(trainsource_dir1):
    shutil.copy(os.path.join(trainsource_dir1, file_name), train_dir)

# Copy the files from the second source directory to the destination directory
for file_name in os.listdir(trainsource_dir2):
    shutil.copy(os.path.join(trainsource_dir2, file_name), train_dir)

#Neutral

trainsource_dir1 = "/content/emotion_detection_fer/train/neutral"
trainsource_dir2 = "/content/train/neutral"
trainsource_dir3 = "/content/val/val/Neutral"
# trainsource_dir4 = "/content/train/train/Neutral"
train_dir = "/content/trainmerged/Neutral"

# Create the destination directory if it doesn't exist
if not os.path.exists(train_dir):
    os.makedirs(train_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(trainsource_dir1):
    shutil.copy(os.path.join(trainsource_dir1, file_name), train_dir)

# Copy the files from the second source directory to the destination directory
for file_name in os.listdir(trainsource_dir2):
    shutil.copy(os.path.join(trainsource_dir2, file_name), train_dir)

#Sad

trainsource_dir1 = "/content/emotion_detection_fer/train/sad"
trainsource_dir2 = "/content/train/sad"
trainsource_dir3 = "/content/val/val/Sad"
# trainsource_dir4 = "/content/train/train/Sad"
train_dir = "/content/trainmerged/Sad"

# Create the destination directory if it doesn't exist
if not os.path.exists(train_dir):
    os.makedirs(train_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(trainsource_dir1):
    shutil.copy(os.path.join(trainsource_dir1, file_name), train_dir)

# Copy the files from the second source directory to the destination directory
for file_name in os.listdir(trainsource_dir2):
    shutil.copy(os.path.join(trainsource_dir2, file_name), train_dir)

#Surprise

trainsource_dir1 = "/content/emotion_detection_fer/train/surprised"
trainsource_dir2 = "/content/train/surprise"
trainsource_dir3 = "/content/val/val/Surprise"
# trainsource_dir4 = "/content/train/train/Surprise"
train_dir = "/content/trainmerged/Surprise"

# Create the destination directory if it doesn't exist
if not os.path.exists(train_dir):
    os.makedirs(train_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(trainsource_dir1):
    shutil.copy(os.path.join(trainsource_dir1, file_name), train_dir)

# Copy the files from the second source directory to the destination directory
for file_name in os.listdir(trainsource_dir2):
    shutil.copy(os.path.join(trainsource_dir2, file_name), train_dir)


train_dir = "/content/trainmerged"

# %%
import os
import shutil
#Joining training data

#Happy

testsource_dir1 = "/content/test/happy"
testsource_dir2 = "/content/emotion_detection_fer/test/happy"
test_dir = "/content/testmerged/Happy"

# Create the destination directory if it doesn't exist
if not os.path.exists(test_dir):
    os.makedirs(test_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(testsource_dir1):
    shutil.copy(os.path.join(testsource_dir1, file_name), test_dir)

#Angry

testsource_dir1 = "/content/test/angry"
testsource_dir2 = "/content/emotion_detection_fer/test/angry"
test_dir = "/content/testmerged/Angry"

# Create the destination directory if it doesn't exist
if not os.path.exists(test_dir):
    os.makedirs(test_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(testsource_dir1):
    shutil.copy(os.path.join(testsource_dir1, file_name), test_dir)

#Disgust

testsource_dir1 = "/content/test/disgust"
testsource_dir2 = "/content/emotion_detection_fer/test/disgusted"
test_dir = "/content/testmerged/Disgust"

# Create the destination directory if it doesn't exist
if not os.path.exists(test_dir):
    os.makedirs(test_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(testsource_dir1):
    shutil.copy(os.path.join(testsource_dir1, file_name), test_dir)


#Fear

testsource_dir1 = "/content/test/fear"
testsource_dir2 = "/content/emotion_detection_fer/test/fearful"
test_dir = "/content/testmerged/Fear"

# Create the destination directory if it doesn't exist
if not os.path.exists(test_dir):
    os.makedirs(test_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(testsource_dir1):
    shutil.copy(os.path.join(testsource_dir1, file_name), test_dir)

#Neutral

testsource_dir1 = "/content/test/neutral"
testsource_dir2 = "/content/emotion_detection_fer/test/neutral"
test_dir = "/content/testmerged/Neutral"

# Create the destination directory if it doesn't exist
if not os.path.exists(test_dir):
    os.makedirs(test_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(testsource_dir1):
    shutil.copy(os.path.join(testsource_dir1, file_name), test_dir)

#Sad

testsource_dir1 = "/content/test/sad"
testsource_dir2 = "/content/emotion_detection_fer/test/sad"
test_dir = "/content/testmerged/Sad"

# Create the destination directory if it doesn't exist
if not os.path.exists(test_dir):
    os.makedirs(test_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(testsource_dir1):
    shutil.copy(os.path.join(testsource_dir1, file_name), test_dir)

#Surprise

testsource_dir1 = "/content/test/surprise"
testsource_dir2 = "/content/emotion_detection_fer/test/surprised"
test_dir = "/content/testmerged/Surprise"

# Create the destination directory if it doesn't exist
if not os.path.exists(test_dir):
    os.makedirs(test_dir)

# Copy the files from the first source directory to the destination directory
for file_name in os.listdir(testsource_dir1):
    shutil.copy(os.path.join(testsource_dir1, file_name), test_dir)

test_dir = "/content/testmerged"

# %%
img_size = 48 #original size of the image

# %%
"""
Data Augmentation
--------------------------
rotation_range = rotates the image with the amount of degrees we provide
width_shift_range = shifts the image randomly to the right or left along the width of the image
height_shift range = shifts image randomly to up or below along the height of the image
horizontal_flip = flips the image horizontally
rescale = to scale down the pizel values in our image between 0 and 1
zoom_range = applies random zoom to our object
validation_split = reserves some images to be used for validation purpose
"""
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(#rotation_range = 180,
                                         width_shift_range = 0.1,
                                         height_shift_range = 0.1,
                                         horizontal_flip = True,
                                         rescale = 1./255,
                                         #zoom_range = 0.2,
                                         validation_split = 0.2
                                        )

test_datagen = ImageDataGenerator(#rotation_range = 180,
                                         width_shift_range = 0.1,
                                         height_shift_range = 0.1,
                                         horizontal_flip = True,
                                         rescale = 1./255,
                                        )

# %%
"""
Applying data augmentation to the images as we read 
them from their respectivve directories
"""
train_generator = train_datagen.flow_from_directory(directory = train_dir,
                                                    target_size = (img_size,img_size),
                                                    batch_size = 128,
                                                    color_mode = "grayscale",
                                                    class_mode = "categorical",
                                                    subset = "training"
                                                   )
validation_generator = train_datagen.flow_from_directory( directory = train_dir,
                                                              target_size = (img_size,img_size),
                                                              batch_size = 128,
                                                              color_mode = "grayscale",
                                                              class_mode = "categorical",
                                                              subset = "validation"
                                                             )
test_generator = test_datagen.flow_from_directory( directory = test_dir,
                                                              target_size = (img_size,img_size),
                                                              batch_size = 128,
                                                              color_mode = "grayscale",
                                                              class_mode = "categorical"
                                                             )
# Out:
# Found 45936 images belonging to 7 classes.
# Found 11482 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
"""
Modeling


model = Sequential()
model.add(Conv2D(filters = 64,kernel_size = (3,3),padding = 'same',activation = 'relu',input_shape=(img_size,img_size,1)))
model.add(MaxPool2D(pool_size = 2,strides = 2))
model.add(BatchNormalization())

model.add(Conv2D(filters = 128,kernel_size = (3,3),padding = 'same',activation = 'relu'))
model.add(MaxPool2D(pool_size = 2,strides = 2))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(filters = 128,kernel_size = (3,3),padding = 'same',activation = 'relu'))
model.add(MaxPool2D(pool_size = 2,strides = 2))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Conv2D(filters = 256,kernel_size = (3,3),padding = 'same',activation = 'relu'))
model.add(MaxPool2D(pool_size = 2,strides = 2))
model.add(BatchNormalization())

model.add(Flatten())
model.add(Dense(units = 128,activation = 'relu',kernel_initializer='he_normal'))
model.add(Dropout(0.25))
model.add(Dense(units = 64,activation = 'relu',kernel_initializer='he_normal'))
model.add(BatchNormalization())
model.add(Dropout(0.25))
model.add(Dense(units = 32,activation = 'relu',kernel_initializer='he_normal'))
model.add(Dense(7,activation = 'softmax'))

"""
# Out:
# "\nModeling\n\n\nmodel = Sequential()\nmodel.add(Conv2D(filters = 64,kernel_size = (3,3),padding = 'same',activation = 'relu',input_shape=(img_size,img_size,1)))\nmodel.add(MaxPool2D(pool_size = 2,strides = 2))\nmodel.add(BatchNormalization())\n\nmodel.add(Conv2D(filters = 128,kernel_size = (3,3),padding = 'same',activation = 'relu'))\nmodel.add(MaxPool2D(pool_size = 2,strides = 2))\nmodel.add(BatchNormalization())\nmodel.add(Dropout(0.25))\n\nmodel.add(Conv2D(filters = 128,kernel_size = (3,3),padding = 'same',activation = 'relu'))\nmodel.add(MaxPool2D(pool_size = 2,strides = 2))\nmodel.add(BatchNormalization())\nmodel.add(Dropout(0.25))\n\nmodel.add(Conv2D(filters = 256,kernel_size = (3,3),padding = 'same',activation = 'relu'))\nmodel.add(MaxPool2D(pool_size = 2,strides = 2))\nmodel.add(BatchNormalization())\n\nmodel.add(Flatten())\nmodel.add(Dense(units = 128,activation = 'relu',kernel_initializer='he_normal'))\nmodel.add(Dropout(0.25))\nmodel.add(Dense(units = 64,activation = 'rel
# ...

# %%
# !pip install tensorflow
# !pip install keras
# !pip install tensorflow==2.12.0
# !pip install keras==2.12.0
# !pip install pixellib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 430.3/430.3 kB 28.8 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 80.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 7.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 20.6 MB/s eta 0:00:00
# ...

# %%
import numpy as np
import pandas as pd
import os
import seaborn as sns
import tensorflow as tf
import keras
from keras.preprocessing import image
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Flatten,Dense,Dropout,BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import np_utils  #esehi dekhrai

import cv2
from keras import regularizers
from keras.applications import VGG16, InceptionResNetV2
from keras.optimizers import Adam,RMSprop,SGD,Adamax

# %%
model= tf.keras.models.Sequential()
model.add(Conv2D(32, kernel_size=(3, 3), padding='same', activation='relu', input_shape=(48, 48,1)))
model.add(Conv2D(64,(3,3), padding='same', activation='relu' ))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,(5,5), padding='same', activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
    
model.add(Conv2D(512,(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(512,(3,3), padding='same', activation='relu', kernel_regularizer=regularizers.l2(0.01)))
model.add(BatchNormalization())
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.25))

model.add(Flatten()) 
model.add(Dense(256,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))
    
model.add(Dense(512,activation = 'relu'))
model.add(BatchNormalization())
model.add(Dropout(0.25))

model.add(Dense(7, activation='softmax'))

model.compile(
    optimizer = Adam(lr=0.0001), 
    loss='categorical_crossentropy', 
    metrics=['accuracy']
  )
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/optimizers/legacy/adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %%
epochs = 60
batch_size = 128

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 48, 48, 32)        320
#
#  conv2d_1 (Conv2D)           (None, 48, 48, 64)        18496
#
#  batch_normalization (BatchN  (None, 48, 48, 64)       256
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 24, 24, 64)       0
#  )
#
#  dropout (Dropout)           (None, 24, 24, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 24, 24, 128)       204928
#
#  batch_normalization_1 (Batc  (None, 24, 24, 128)      512
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 128)      0
#  2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 12, 12, 512)       590336
#
#  batch_normalization_2 (Batc  (None, 12, 12, 512)      2048
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 6, 6, 512)        0
#  2D)
#
# ...

# %%
from keras.utils import plot_model
plot_model(model, to_file='model.png')

# %%
history = model.fit(x = train_generator,epochs = epochs,validation_data = validation_generator)
# Out:
# Epoch 1/60
# 359/359 [==============================] - 72s 168ms/step - loss: 9.0463 - accuracy: 0.1977 - val_loss: 8.1326 - val_accuracy: 0.2503
# Epoch 2/60
# 359/359 [==============================] - 48s 134ms/step - loss: 7.5735 - accuracy: 0.2506 - val_loss: 6.7990 - val_accuracy: 0.2545
# Epoch 3/60
# 359/359 [==============================] - 48s 134ms/step - loss: 6.2224 - accuracy: 0.2922 - val_loss: 5.7663 - val_accuracy: 0.2903
# Epoch 4/60
# 359/359 [==============================] - 48s 134ms/step - loss: 5.0499 - accuracy: 0.3420 - val_loss: 4.4147 - val_accuracy: 0.3944
# Epoch 5/60
# 359/359 [==============================] - 47s 130ms/step - loss: 4.1200 - accuracy: 0.3817 - val_loss: 3.6148 - val_accuracy: 0.4214
# Epoch 6/60
# 359/359 [==============================] - 48s 133ms/step - loss: 3.3974 - accuracy: 0.4171 - val_loss: 3.1857 - val_accuracy: 0.4192
# Epoch 7/60
# ...

# %%
import matplotlib.pyplot as plt

fig , ax = plt.subplots(1,2)
train_acc = history.history['accuracy']
train_loss = history.history['loss']
fig.set_size_inches(12,4)

ax[0].plot(history.history['accuracy'])
ax[0].plot(history.history['val_accuracy'])
ax[0].set_title('Training Accuracy vs Validation Accuracy')
ax[0].set_ylabel('Accuracy')
ax[0].set_xlabel('Epoch')
ax[0].legend(['Train', 'Validation'], loc='upper left')

ax[1].plot(history.history['loss'])
ax[1].plot(history.history['val_loss'])
ax[1].set_title('Training Loss vs Validation Loss')
ax[1].set_ylabel('Loss')
ax[1].set_xlabel('Epoch')
ax[1].legend(['Train', 'Validation'], loc='upper left')

plt.show()

# %%
# load the saved model
model.save('model_optimal.h5')

# %%
from keras.models import load_model

# Load the saved model
model = load_model('model_optimal.h5')

# Load test data using ImageDataGenerator
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
        test_dir,
        target_size=(img_size, img_size),
        batch_size=1,
        color_mode='grayscale',
        class_mode='categorical',
        shuffle=False)

# Use the model to predict classes for test data
y_pred = model.predict(test_generator)
y_pred_classes = np.argmax(y_pred, axis=1)

# Get true classes for test data
y_true = test_generator.classes

# Print classification report and confusion matrix
from sklearn.metrics import classification_report, confusion_matrix
print(classification_report(y_true, y_pred_classes))
print(confusion_matrix(y_true, y_pred_classes))
# Out:
# Found 7178 images belonging to 7 classes.
# 7178/7178 [==============================] - 22s 3ms/step
#               precision    recall  f1-score   support
#
#            0       0.56      0.65      0.60       958
#            1       0.71      0.63      0.67       111
#            2       0.56      0.41      0.47      1024
#            3       0.87      0.87      0.87      1774
#            4       0.58      0.71      0.64      1233
#            5       0.57      0.51      0.54      1247
#            6       0.80      0.78      0.79       831
#
#     accuracy                           0.67      7178
#    macro avg       0.66      0.65      0.65      7178
# weighted avg       0.67      0.67      0.67      7178
#
# [[ 623   16   64   35  106   96   18]
#  [  26   70    2    3    2    7    1]
#  [ 157    7  423   28  141  191   77]
#  [  45    0   24 1535  106   30   34]
#  [  83    2   48   65  879  138   18]
#  [ 144    3  125   58  263  639   15]
# ...

# %%
from PIL import Image

img = Image.open("/content/testmerged/Angry/PrivateTest_12191716.jpg").resize((48, 48)).convert('L')
img = np.array(img)
plt.imshow(img, cmap="gray")
print(img.shape) #prints (48,48) that is the shape of our image
# Out:
# (48, 48)

# %%
label_dict = {0:'Angry',1:'Disgust',2:'Fear',3:'Happy',4:'Neutral',5:'Sad',6:'Surprise'}

# %%
img = np.expand_dims(img,axis = 0) #makes image shape (1,48,48)
img = img.reshape(1,48,48,1)
result = model.predict(img)
result = list(result[0])
print(result)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# [1.0, 0.0, 1.5568996e-21, 0.0, 0.0, 0.0, 0.0]

# %%
img_index = result.index(max(result))
print(label_dict[img_index])
plt.show()
# Out:
# Angry

# %%
y_pred = model.predict(test_generator)

# Get the class with the highest probability for each sample
y_pred_labels = []
for i in y_pred:
    y_pred_labels.append(np.argmax(i))

y_actual = test_generator.classes[test_generator.index_array]

from sklearn import metrics
cm = metrics.confusion_matrix(y_actual, y_pred_labels)
disp = metrics.ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.show()
# Out:
# 7178/7178 [==============================] - 20s 3ms/step

# %%
from sklearn.metrics import confusion_matrix, classification_report
print(classification_report(y_actual, y_pred_labels, digits=4))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.5592    0.6503    0.6014       958
#            1     0.7071    0.6306    0.6667       111
#            2     0.5566    0.4131    0.4742      1024
#            3     0.8697    0.8653    0.8675      1774
#            4     0.5810    0.7129    0.6402      1233
#            5     0.5726    0.5124    0.5408      1247
#            6     0.7990    0.7798    0.7893       831
#
#     accuracy                         0.6711      7178
#    macro avg     0.6636    0.6521    0.6543      7178
# weighted avg     0.6717    0.6711    0.6679      7178

# %%
train_loss, train_acc = model.evaluate(train_generator)
val_loss, val_acc   = model.evaluate(validation_generator)
test_loss, test_acc   = model.evaluate(test_generator)
print("final train accuracy = {:.2f} , validation accuracy = {:.2f}, testing accuracy = {:.2f}".format(train_acc*100, val_acc*100, test_acc*100))
# Out:
# ...
# 7178/7178 [==============================] - 34s 5ms/step - loss: 1.3900 - accuracy: 0.6711
# final train accuracy = 79.18 , validation accuracy = 73.81, testing accuracy = 67.11

# %%
model.save_weights('model_weights.h5')
